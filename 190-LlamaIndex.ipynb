# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/GPT-Web/blob/main/190-LlamaIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama-index

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
import requests
import os

url = 'https://raw.githubusercontent.com/JSJeong-me/GPT-Web/main/images/paul_graham_essay.txt'
output_dir = './data'
file_name = 'paul_graham_essay.txt'
output_path = os.path.join(output_dir, file_name)

# %%
from google.colab import userdata
import openai
import os

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
openai.api_key  = os.environ["OPENAI_API_KEY"]

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.readers import SimpleDirectoryReader

documents = SimpleDirectoryReader("./data").load_data()
index = VectorStoreIndex.from_documents(documents)
# Out:
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.

# %%
# Ensure the data directory exists
os.makedirs(output_dir, exist_ok=True)

response = requests.get(url)
response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)

with open(output_path, 'wb') as f:
    f.write(response.content)

print(f"File downloaded and saved to {output_path}")
# Out:
# File downloaded and saved to ./data/paul_graham_essay.txt

# %%
query_engine = index.as_query_engine()
response = query_engine.query("What is the author name? in short answer")
print(response.response)
# Out:
# Paul Graham

# %%
response = query_engine.query("고양이 다리는 몇개인가요?")
print(response.response)
# Out:
# 3개
